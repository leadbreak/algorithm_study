# %% [markdown]
# <a href="https://colab.research.google.com/github/leadbreak/algorithm_study/blob/main/Weekly_Algorithm_Study_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 01.
# https://programmers.co.kr/learn/courses/30/lessons/86491

# %%
def solution(sizes):
    max_lines = []
    min_lines = []
    for size in sizes :
        max_lines.append(max(size))
        min_lines.append(min(size))

    answer = max(max_lines) * max(min_lines)
    return answer

# %%
def solution(sizes):

    return max(max(x) for x in sizes) * max(min(y) for y in sizes)

# %% [markdown]
# 02.
# https://programmers.co.kr/learn/courses/30/lessons/17677

# %%
# 1차

import re

def solution(str1, str2):
    str1 = str1.lower()
    str2 = str2.lower()

    list1 = []
    list2 = []

    for i in range(len(str1)-1) :
        target1 = str1[i:i+2]
        if len(target1) == len(re.sub(r"[^a-z]","", target1)) :
            list1.append(str1[i:i+2])

    for i in range(len(str2)-1) :
        target2 = str2[i:i+2]
        if len(target2) == len(re.sub(r"[^a-z]","", target2)) :
            list2.append(str2[i:i+2])
    
    if list1 == list2 :
        return 65536
    else :
        total = 0
        inter = 0
        if len(list1) > len(list2) :
            longer = list1.copy()
            shorter = list2.copy()
        else :
            longer = list2.copy()
            shorter = list1.copy()

        while longer :
            total += 1
            if longer[0] in shorter :

                shorter.remove(longer[0])
                longer.remove(longer[0])                
                inter += 1
            else :
                longer.remove(longer[0])

        total += len(shorter)

        return int((inter/total) * 65536)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
str1 = "handshake"
str2 = "shake hands"

solution(str1, str2)
# Out:
# sh ['sh', 'ha', 'ak', 'ke', 'ha', 'an', 'nd', 'ds'] ['ha', 'an', 'nd', 'ds', 'sh', 'ha', 'ak', 'ke']
# ha ['ha', 'ak', 'ke', 'ha', 'an', 'nd', 'ds'] ['ha', 'an', 'nd', 'ds', 'ha', 'ak', 'ke']
# ak ['ak', 'ke', 'ha', 'an', 'nd', 'ds'] ['an', 'nd', 'ds', 'ha', 'ak', 'ke']
# ke ['ke', 'ha', 'an', 'nd', 'ds'] ['an', 'nd', 'ds', 'ha', 'ke']
# ha ['ha', 'an', 'nd', 'ds'] ['an', 'nd', 'ds', 'ha']
# an ['an', 'nd', 'ds'] ['an', 'nd', 'ds']
# nd ['nd', 'ds'] ['nd', 'ds']
# ds ['ds'] ['ds']
# 8 8
# 65536

# %%
str1 = "FRANCE"
str2 = "french"

solution(str1, str2)
# Out:
# 13107

# %%
# 2차

import re

def solution(str1, str2):
    str1 = str1.lower()
    str2 = str2.lower()

    list1 = [str1[i:i+2] for i in range(len(str1)-1) if len(str1[i:i+2]) == len(re.sub(r"[^a-z]","", str1[i:i+2]))]
    list2 = [str2[i:i+2] for i in range(len(str2)-1) if len(str2[i:i+2]) == len(re.sub(r"[^a-z]","", str2[i:i+2]))]
    
    if list1 == list2 :
        return 65536
    else :
        total = 0
        inter = 0
        if len(list1) > len(list2) :
            longer = list1.copy()
            shorter = list2.copy()
        else :
            longer = list2.copy()
            shorter = list1.copy()

        while longer :
            total += 1
            if longer[0] in shorter :

                shorter.remove(longer[0])
                longer.remove(longer[0])                
                inter += 1
            else :
                longer.remove(longer[0])

        total += len(shorter)

        return int((inter/total) * 65536)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 다른 사람의 풀이 중 BEST CODE

import re

def solution(str1, str2):
    str1 = [str1[i:i+2].lower() for i in range(0, len(str1)-1) if not re.findall('[^a-zA-Z]+', str1[i:i+2])]
    str2 = [str2[i:i+2].lower() for i in range(0, len(str2)-1) if not re.findall('[^a-zA-Z]+', str2[i:i+2])]

    gyo = set(str1) & set(str2)
    hap = set(str1) | set(str2)

    if len(hap) == 0 :
        return 65536

    gyo_sum = sum([min(str1.count(gg), str2.count(gg)) for gg in gyo])
    hap_sum = sum([max(str1.count(hh), str2.count(hh)) for hh in hap])

    return int((gyo_sum/hap_sum)*65536)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3차

import re

def solution(str1, str2):
    str1 = str1.lower()
    str2 = str2.lower()

    list1 = [str1[i:i+2] for i in range(len(str1)-1) if len(str1[i:i+2]) == len(re.sub(r"[^a-z]","", str1[i:i+2]))]
    list2 = [str2[i:i+2] for i in range(len(str2)-1) if len(str2[i:i+2]) == len(re.sub(r"[^a-z]","", str2[i:i+2]))]
    
    if list1 == list2 :
        return 65536

    inter = list(set(list1) & set(list2))
    union = list(et(list1) | set(list2))

    if not union :
        return 65536

    inter_sum = sum([min(list1.count(i), list2.count(i)) for i in inter])
    union_sum = sum([max(list1.count(u), list2.count(u)) for u in union])


    return int((inter_sum/union_sum) * 65536)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4차

import re

# 영어를 소문자로 변환하고, 인식하기 쉽도록 그 외 글자를 @로 치환
def preprocessing(str1, str2) :
    str1 = str1.lower()
    str2 = str2.lower()

    str1 = re.sub(r"[^A-Za-z]","@", str1)
    str2 = re.sub(r"[^a-z]","@", str2)

    return str1, str2

def solution(str1, str2):
    
    str1, str2 = preprocessing(str1, str2)
    
    # 만약 중간에 @가 포함되어 있으면 그 두 글자 집합은 제외
    list1 = [str1[i:i+2] for i in range(len(str1)-1) if not "@" in str1[i:i+2]]
    list2 = [str2[i:i+2] for i in range(len(str2)-1) if not "@" in str2[i:i+2]]
    
    ### 숏컷 1 : 만약 두 리스트가 같으면 65536을 출력하고 종료
    list1.sort()
    list2.sort()
    
    if list1 == list2 :
        return 65536
    ###
    
    # 교집합과 합집합의 경우의 수를 모두 구한 뒤, 각 경우에 해당하는 수를 카운트
    # 카운트한 값들을 기준으로 교집합은 최소, 합집합은 최대를 기준으로 합산
    inter = list(set(list1) & set(list2))
    union = list(set(list1) | set(list2))
    
    ### 숏컷 2 : 만약 교집합이 0이면 0을 출력하고 종료 
    if not inter :
        return 0

    inter_sum = sum([min(list1.count(i), list2.count(i)) for i in inter])
    union_sum = sum([max(list1.count(u), list2.count(u)) for u in union])

    return int((inter_sum/union_sum) * 65536)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
