# %% [markdown]
# #21.02.10

# %% [markdown]
# ##1. SortingMerge Sort: Counting Inversions
# https://www.hackerrank.com/challenges/ctci-merge-sort/problem?h_l=interview&playlist_slugs%5B%5D=interview-preparation-kit&playlist_slugs%5B%5D=sorting

# %%
# time-limit 등 40점
def countInversions(arr):
    
    cnt = 0
    length = n
    
    while arr :        
       
        small = min(arr)
        big = max(arr)        
        
        if arr[0] != small :
            cnt += arr.index(small)
            arr.remove(small)
            length -= 1
        else :
            arr.remove(small)
            length -= 1
            
        if len(arr) <= 1 :
            break
        
        if arr[-1] != big :
            cnt += (length - arr.index(big) - 1)
            arr.remove(big)
            length -= 1
        else :
            arr.remove(big)       
            length -= 1     
    
    return cnt

# %%
arr2 = [2,1,3,1,2] # return2 = 4
n = 5
countInversions(arr2)
# Out:
# 4

# %%
# 각 리스트를 최소 단위까지 나누고, 이를 DFS 방식으로 해결
def countInversions(arr):
    cnt = 0 
    if len(arr) > 1:
        mid = len(arr)//2
        left = arr[:mid]
        right = arr[mid:]
        cnt += countInversions(left)
        cnt += countInversions(right)
        
        i = j = k = 0
        while i < len(left) and j < len(right):
            if left[i] <= right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
                cnt += len(left) - i
            k += 1
        
        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1
            
        
        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

    return cnt

# %% [markdown]
# ##2. Stacks and Queues : Castle on the Grid
# https://www.hackerrank.com/challenges/castle-on-the-grid/problem?h_l=interview&playlist_slugs%5B%5D=interview-preparation-kit&playlist_slugs%5B%5D=stacks-queues

# %%
# 대용량 데이터가 들어있는 1,2,3,4 예제가 풀리지 않음
from collections import deque

def minimumMoves(grid, startX, startY, goalX, goalY):
    
    dx = [1,0,-1,0]
    dy = [0,1,0,-1]
    
    ch = [[0] * n for _ in range(n)]
    dis = [[999] * n for _ in range(n)]
    dis[startX][startY] = 0
    ch[startX][startY] = 1
    
    Q = deque()
    res = 1000000000
    cnt = 1
    Q.append((startX, startY))

    for k in range(4) :
      x = startX + dx[k]
      y = startY + dy[k]
      if 0 <= x < n and 0 <= y < n and grid[x][y] != "X" :
        dis[x][y] = 1
    
    while Q :
        now = Q.popleft()

        if now == (goalX, goalY) :
          break

        for i in range(4) :            
            x = now[0] + dx[i]
            y = now[1] + dy[i]
            
            if 0 <= x < n and 0 <= y < n and grid[x][y] != "X" and ch[x][y] == 0 :
                ch[x][y] = 1
                Q.append((x,y))

                try :
                  if dis[now[0]][now[1]] == dis[now[0]-dx[i]][now[1]-dy[i]] and dis[now[0]][now[1]] != 999 :
                    dis[x][y] = min(dis[now[0]][now[1]], dis[x][y])
                  else :
                    dis[x][y] = min(dis[now[0]][now[1]] + 1,dis[x][y])
                except :
                  dis[x][y] = min(dis[now[0]][now[1]] + 1,dis[x][y])
                
                new_x = x + dx[i]
                new_y = y + dy[i]
                while True :
                  if new_x < 0 or new_x == n or new_y < 0 or new_y == n or grid[new_x][new_y] == "X" :
                    break
                  else :
                    dis[new_x][new_y] = min(dis[x][y],dis[new_x][new_y])
                    new_x += dx[i]
                    new_y += dy[i]    

        

    return dis

# %%
import pandas as pd

grid = ['.....X..X.X.X..X.....X.......X...XX....X...X.....X...X..........X..X...X............XX..........X...', 'X........X......X..........X..XXX..XX........XX.......XX.XX.XX...X...X....XX...X.........X....X.....', '........X.X.......X.....X.......X.......X..X..X.....X.XX........X.X..............X...X........XX.X..', '..........X....X...X..........X.X...............X.X.XX.X.X......X....X.......X.....X.XX.....X..X.X..', '.......X..X.....X...X...................X.X.
', '......X.....X.X..XX..XX...X.........X...X.X........X..........X.X.X........XX..X.XX......X.......XX.', '.......XXX......X......X.....X......XXX....X......X..X..........XX.X..X....XX....X........XX........', '...X...XX..X.............X.X...X.....X.....X....X..X.X.XX..X..............X....X.....X.......X......', 'X.X..............X....X.........X.X...X..XX..X...X.X.....X.XX..X........XXXX.....X......X..........X', '.......X..X...X.........X...X........XX.......X........X.X...........X.X.....X..............X....X..', '.XX.X...X.......XXX...XX.X......X.............X..XXX..XX...X............X.X.......X......X....X.....', '........X...........X..XX.X.X.X......X.X....XX..X......X.......XX......X...X......XXX........X......', '..............X.X......X.......X...XX..XX.X.XX..X.................X..X....X........XX.X.....X......X', 'X.........X...XX...X.X..X.X.......X..X.....X.X.........X..X.......X......X..X...........X....X...X..', '...X...........X............XX..................X.........XX....X....................X...XX....X....', '..X........X......XXX......X..............X...XX.......X.X.X.XX.........XX......X...........X.......', '...X......XXXX.........XXX.....X.....XXXXX.......X...X.X....XX...X..X...X...X...XX.....X..X.X.......', '....X.X..X.....XX...........X.X.X................X...X.X.......X......X.X.....X.X.......X.....X....X', 'X..X..XX.XXX..........X....X................X.......X.....XX.X...X.X.X..X.....XX.X......X..XX.X.....', '...XX.X..XX.....X......X.........X...X....XX.....XXXX..........XX.X..XX..X.X....X...X....X....X..XX.', 'XX......X....XXX....X.....X...........X..XX..X.......X.......X.XX..X..XX.X..............X......X..X.', '......X....X....X..X...X......X...X.X..X.....X........X..XX....X...X..X.XX........XX...X...X..XX....', 'XX.X.X...X....X..X..X.......X...................X.X..X...X......X..X.........X........X.X.X.........', 'XX...XX....X.XX...X.XX..X..X..X....XX...X..X....X....X.....X....XX.............X......XX.X..X....X..', '.X....X......X....X..........X..........................X..X.....XX.X.......X...X.X......X..........', '...X.......XX.............X..XXX..X..X.........X...X..X.....X.........X...X.....X...................', '.X......X..XX....X.X....XX...............XX........X......X........X.X...................X.X......XX']
n = 40
startX = 34
startY = 28
goalX = 16
goalY = 8

a = minimumMoves(grid, startX, startY, goalX, goalY)

df = pd.DataFrame()

for i in range(n) :
  for j in range(n) :
    df[i] = pd.Series(a[i])

df
# Out:
#      0    1    2    3    4    5    6   ...   33   34   35   36   37   38   39
# 0   999  999  999  999  999  999  999  ...   12    9    7   11   13   11   13
# 1   999  999  999  999  999  999    7  ...   12    9    7   11   12   11   13
# 2   999  999  999  999  999  999    7  ...   11    9    7   11  999   11   13
# 3   999  999  999  999  999  999    7  ...  999    8    7   15   13   11   13
# 4   999  999  999  999  999  999    7  ...    8  999    7   14   13   11   13
# 5   999  999  999  999  999  999    7  ...    7    6    7  999   13   11   12
# 6   999  999  999  999  999  999    7  ...  999    6    7   15   13   11  999
# 7   999  999  999  999  999  999    7  ...    6    6    7   14   13   11    9
# 8   999  999  999  999  999  999    7  ...    6    6    7  999   13   11    9
# 9   999  999  999  999  999  999    7  ...    6    6    6  999   12   11    9
# 10  999  999  999  999  999  999    7  ...    6    6  999    8  999   10    9
# ...

# %%
grid = ['.X..XX...X', 'X.........','.X.......X','..........','........X.','.X...XXX..','.....X..XX','.....X.X..','..........','.....X..XX']
n = 10
startX = 9
startY = 1
goalX = 9
goalY = 6

minimumMoves(grid, startX, startY, goalX, goalY)
# Out:
# [[999, 999, 2, 2, 999, 999, 999, 999, 999, 999],
#  [999, 999, 2, 2, 2, 999, 999, 999, 999, 999],
#  [2, 999, 2, 2, 2, 999, 999, 999, 999, 999],
#  [2, 999, 2, 2, 2, 999, 999, 999, 999, 999],
#  [2, 2, 2, 2, 2, 999, 999, 999, 999, 999],
#  [2, 999, 2, 2, 2, 999, 999, 999, 999, 999],
#  [2, 1, 2, 2, 2, 999, 3, 999, 999, 999],
#  [2, 1, 2, 2, 2, 999, 3, 999, 999, 999],
#  [2, 1, 2, 2, 2, 2, 2, 2, 2, 2],
#  [1, 0, 1, 1, 1, 999, 3, 999, 999, 999]]

# %%
grid = ['.X.','.X.', '...']
n = 3
startX = 0
startY = 0
goalX = 0
goalY = 2

minimumMoves(grid, startX, startY, goalX, goalY)
# Out:
# [[0, 999, 3], [1, 999, 3], [1, 2, 2]]

# %%
stack = deque()
stack.append((1,2))
stack.append((3,4))
stack.popleft()
# Out:
# (1, 2)

# %%
# 풀이
def minimumMoves(grid, startX, startY, goalX, goalY):
    # construct 2D grid
    grid = [row for row in grid]
    # initiate dictionary of coordinates:distances
    distance = {(x, y): math.inf for x in range(len(grid)) for y in range(len(grid))}
    distance[(startX, startY)] = 0

    stack = deque()
    stack.append((startX, startY))
    while stack:
        # x and y coordinates of current node
        cx, cy = stack.pop()
        # distance of current node
        cdistance = distance[(cx, cy)]
        # return distance if current node is goal
        if (cx, cy) == (goalX, goalY):
            return cdistance

        neighbors = []

        # explore up
        x = cx - 1
        while x > -1 and grid[x][cy] != 'X':
            neighbors.append((x, cy))
            x -= 1

        # explore down
        x = cx + 1
        while x < n and grid[x][cy] != 'X':
            neighbors.append((x, cy))
            x += 1

        # explore left
        y = cy - 1
        while y > -1 and grid[cx][y] != 'X':
            neighbors.append((cx, y))
            y -= 1

        # explore right
        y = cy + 1
        while y < n and grid[cx][y] != 'X':
            neighbors.append((cx, y))
            y += 1
    
        # add nodes whose distances have decreased to the stack
        for node in neighbors:
            if cdistance + 1 < distance[node]:
                distance[node] = cdistance + 1
                stack.appendleft(node)

# %% [markdown]
# ##3. GraphsDFS: Connected Cell in a Grid
# https://www.hackerrank.com/challenges/ctci-connected-cell-in-a-grid/problem?h_l=interview&playlist_slugs%5B%5D=interview-preparation-kit&playlist_slugs%5B%5D=graphs

# %%
# Complete!
def maxRegion(x,y):
    global cnt
    
    # ch[x][y] = 1
    for i in range(8) :
        xx = x + dx[i]
        yy = y + dy[i]
        
        if 0 <= xx < n and 0 <= yy < m and ch[xx][yy] == 0 and grid[xx][yy] == 1 :
            ch[xx][yy] = 1
            cnt += 1
            maxRegion(xx,yy)

    return
  

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    m = int(input())
    
    dx = [0,1,1,1,0,-1,-1,-1]
    dy = [1,1,0,-1,-1,-1,0,1]
    
    ch = [[0] * m for _ in range(n)]
    result = []
    cnt = 0

    grid = []

    for _ in range(n):
        grid.append(list(map(int, input().rstrip().split())))
        
    for i in range(n) :
        for j in range(m) :
            if ch[i][j] == 0 and grid[i][j] == 1 :
                ch[i][j] = 1
                cnt = 1
                maxRegion(i,j)
                result.append(cnt)

    res = max(result)
    
    fptr.write(str(res) + '\n')

    fptr.close()
